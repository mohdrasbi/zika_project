# %%
import pandas as pd
import numpy as np
import glob
from difflib import SequenceMatcher
import re

# %% [markdown]
# # Helper functions

# %%
def addToPrev(prev, index, text):
    prev[index] = text
    return prev

################################

def inPrev(prev, text, tot_sims):
    for message in prev:
        if SequenceMatcher(None, text, message).ratio() >= 0.7:
            tot_sims.setdefault(message, []).append(text)
            return True, tot_sims
    return False, tot_sims

################################

def reduce_tweets(tweets, reduceBy): 
    prev = [""]*reduceBy
    index = 0
    tot_sims = {}
    filtered_tweets = []
    
    for _tweet in tweets:
        in_prev, tot_sims = inPrev(prev, _tweet, tot_sims)
        if not in_prev:
            prev = addToPrev(prev, index, _tweet)
            index = (index + 1) % reduceBy
            filtered_tweets.append(_tweet)
    
    return filtered_tweets

################################

def check_sim(check_word, sims):
    words = ["mosquito", "protect", "repel", "spray"]
    for word in words:
        ratio = SequenceMatcher(None, check_word, word).ratio()
        if ratio >= 0.7:
            sims[check_word] = ratio
            return True, sims
    return False, sims

################################

def check_sim_v2(check_word, sims):
    if re.compile('m[a-z]+sq[a-z]+to').match(check_word):
        sims.append(check_word)
        return True, sims
    
    words = ['repel', 'protect', 'spray', 
             "proteger", "repeler", "rociar","repelir"]

    for word in words:
        if re.compile(word).search(check_word):
            sims.append(check_word)
            return True, sims
    
    return False, sims

# %% [markdown]
# # Stats

# %%
path = "/Users/datacsv/*.csv"

# %%
temp_df = pd.read_csv("/Users/datacsv/tweets_2015_08_16.csv")
filtered_df = pd.DataFrame(columns=temp_df.columns)
data = {}
regex = re.compile('[^a-zA-Z]')
index = 0
sims = []
for file in glob.glob(path):
    df = pd.read_csv(file)
    df[df == "None"] = np.nan
    df = df.dropna(subset=["City", "State", "Country"], how='all')
    df = df.fillna("")

    #Find number of total tweets in a location
    group_sums = df.groupby(["City", "State", "Country"])["Message"].agg(np.size)
    cities = group_sums.index.get_level_values(0)
    states = group_sums.index.get_level_values(1)
    countries = group_sums.index.get_level_values(2)
    
    for city, state, country in zip(cities, states, countries):
        location = (city, state, country)
        data[location] = data.get(location, {})
        data[location]['num_total'] = data[location].get('num_total', 0)
        data[location]['num_total'] += group_sums.loc[city, state, country]
    
    #Filter tweets, then store in filtered_df
    for i in df.index:
        tweet = df.loc[i]["Message"]
        if tweet[0:2] != "RT":
            for word in tweet.lower().split():
                    isSimilar, sims = check_sim_v2(regex.sub('', word), sims)
                    if(isSimilar):
                        filtered_df.loc[index] = df.loc[i]
                        index += 1
                        break
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
group_sums = filtered_df.groupby(["City", "State", "Country"])["Message"].agg(np.size)
cities = group_sums.index.get_level_values(0)
states = group_sums.index.get_level_values(1)
countries = group_sums.index.get_level_values(2)

for city, state, country in zip(cities, states, countries):
    location = (city, state, country)
    data[location] = data.get(location, {})
    data[location]['filtered_total'] = data[location].get('filtered_total', 0)
    data[location]['filtered_total'] += group_sums.loc[city, state, country]

# %%
data
# Out:
# {('', '', 'Afghanistan'): {'num_total': 202, 'filtered_total': 11},
#  ('', '', 'Algeria'): {'num_total': 696, 'filtered_total': 9},
#  ('', '', 'Argentina'): {'num_total': 51622, 'filtered_total': 2520},
#  ('', '', 'Australia'): {'num_total': 17577, 'filtered_total': 959},
#  ('', '', 'Bangladesh'): {'num_total': 3247, 'filtered_total': 209},
#  ('', '', 'Barbados'): {'num_total': 1985, 'filtered_total': 107},
#  ('', '', 'Belize'): {'num_total': 658, 'filtered_total': 33},
#  ('', '', 'Bolivia'): {'num_total': 4147, 'filtered_total': 172},
#  ('', '', 'Brazil'): {'num_total': 200379, 'filtered_total': 4964},
#  ('', '', 'Brunei'): {'num_total': 351, 'filtered_total': 17},
#  ('', '', 'Bulgaria'): {'num_total': 589, 'filtered_total': 17},
#  ('', '', 'Cambodia'): {'num_total': 396, 'filtered_total': 22},
#  ('', '', 'Canada'): {'num_total': 41986, 'filtered_total': 2834},
#  ('', '', 'Cayman Islands'): {'num_total': 755, 'filtered_total': 61},
#  ('', '', 'Chile'): {'num_total': 30648, 'filtered_total': 2062},
#  ('', '', 'Colombia'): {'num_total': 81586, 'filtered_total': 3019},
#  ('', '', 'Costa Rica'): {'num_total': 10547, 'filtered_total': 481},
#  ('', '', 'Cuba'): {'num_total': 28323, 'filtered_total': 793},
#  ('', '', 'Cyprus'): {'num_total': 1055, 'filtered_total': 44},
#  ('', '', 'Denmark'): {'num_total': 881, 'filtered_total': 38},
#  ('', '', 'Dominican Republic'): {'num_total': 30843, 'filtered_total': 1465},
#  ('', '', 'Ecuador'): {'num_total': 24071, 'filtered_total': 890},
#  ('', '', 'Egypt'): {'num_total': 3524, 'filtered_total': 232},
#  ('', '', 'El Salvador'): {'num_total': 13462, 'filtered_total': 433},
#  ('', '', 'Ethiopia'): {'num_total': 453, 'filtered_total': 21},
#  ('', '', 'Fiji'): {'num_total': 577, 'filtered_total': 19},
#  ('', '', 'Finland'): {'num_total': 2821, 'filtered_total': 121},
#  ('', '', 'France'): {'num_total': 31406, 'filtered_total': 356},
#  ('', '', 'Germany'): {'num_total': 14296, 'filtered_total': 668},
#  ('', '', 'Ghana'): {'num_total': 2880, 'filtered_total': 102},
#  ('', '', 'Greece'): {'num_total': 2137, 'filtered_total': 68},
#  ('', '', 'Guadeloupe'): {'num_total': 2552, 'filtered_total': 26},
#  ('', '', 'Haiti'): {'num_total': 3902, 'filtered_total': 120},
#  ('', '', 'Honduras'): {'num_total': 28549, 'filtered_total': 311},
#  ('', '', 'Hungary'): {'num_total': 452, 'filtered_total': 16},
#  ('', '', 'India'): {'num_total': 52541, 'filtered_total': 3669},
#  ('', '', 'Indonesia'): {'num_total': 53979, 'filtered_total': 877},
#  ('', '', 'Iraq'): {'num_total': 934, 'filtered_total': 52},
#  ('', '', 'Ireland'): {'num_total': 8146, 'filtered_total': 285},
#  ('', '', 'Israel'): {'num_total': 1745, 'filtered_total': 89},
#  ('', '', 'Italy'): {'num_total': 16320, 'filtered_total': 532},
#  ('', '', 'Jamaica'): {'num_total': 16343, 'filtered_total': 1155},
#  ('', '', 'Japan'): {'num_total': 8862, 'filtered_total': 308},
#  ('', '', 'Kenya'): {'num_total': 9310, 'filtered_total': 599},
#  ('', '', 'Latvia'): {'num_total': 403, 'filtered_total': 11},
#  ('', '', 'Lebanon'): {'num_total': 1920, 'filtered_total': 89},
#  ('', '', 'Lithuania'): {'num_total': 148, 'filtered_total': 3},
#  ('', '', 'Macedonia'): {'num_total': 184, 'filtered_total': 3},
#  ('', '', 'Madagascar'): {'num_total': 4439, 'filtered_total': 62},
#  ('', '', 'Malaysia'): {'num_total': 31738, 'filtered_total': 573},
#  ('', '', 'Maldives'): {'num_total': 4487, 'filtered_total': 78},
#  ('', '', 'Martinique'): {'num_total': 3279, 'filtered_total': 38},
#  ('', '', 'Mexico'): {'num_total': 39693, 'filtered_total': 1580},
#  ('', '', 'Montenegro'): {'num_total': 393, 'filtered_total': 3},
#  ('', '', 'Morocco'): {'num_total': 635, 'filtered_total': 17},
#  ('', '', 'Nepal'): {'num_total': 2984, 'filtered_total': 79},
#  ('', '', 'Netherlands'): {'num_total': 17859, 'filtered_total': 420},
#  ('', '', 'New Zealand'): {'num_total': 3238, 'filtered_total': 221},
#  ('', '', 'Nicaragua'): {'num_total': 11014, 'filtered_total': 305},
#  ('', '', 'Nigeria'): {'num_total': 35628, 'filtered_total': 2672},
#  ('', '', 'Norway'): {'num_total': 4346, 'filtered_total': 183},
#  ('', '', 'Oman'): {'num_total': 498, 'filtered_total': 19},
#  ('', '', 'Pakistan'): {'num_total': 11156, 'filtered_total': 930},
#  ('', '', 'Panama'): {'num_total': 9838, 'filtered_total': 399},
#  ('', '', 'Paraguay'): {'num_total': 10882, 'filtered_total': 272},
#  ('', '', 'Peru'): {'num_total': 7712, 'filtered_total': 188},
#  ('', '', 'Philippines'): {'num_total': 18613, 'filtered_total': 1117},
#  ('', '', 'Poland'): {'num_total': 2279, 'filtered_total': 59},
#  ('', '', 'Portugal'): {'num_total': 8220, 'filtered_total': 342},
#  ('', '', 'Qatar'): {'num_total': 628, 'filtered_total': 25},
#  ('', '', 'Romania'): {'num_total': 1877, 'filtered_total': 34},
#  ('', '', 'Russia'): {'num_total': 690, 'filtered_total': 25},
#  ('', '', 'Serbia'): {'num_total': 895, 'filtered_total': 20},
#  ('', '', 'Somalia'): {'num_total': 315, 'filtered_total': 14},
#  ('', '', 'South Africa'): {'num_total': 9043, 'filtered_total': 354},
#  ('', '', 'South Korea'): {'num_total': 1163, 'filtered_total': 28},
#  ('', '', 'Spain'): {'num_total': 10695, 'filtered_total': 441},
#  ('', '', 'Sri Lanka'): {'num_total': 2331, 'filtered_total': 131},
#  ('', '', 'St. Lucia'): {'num_total': 788, 'filtered_total': 42},
#  ('', '', 'Sweden'): {'num_total': 3845, 'filtered_total': 83},
#  ('', '', 'Switzerland'): {'num_total': 4546, 'filtered_total': 147},
#  ('', '', 'Taiwan'): {'num_total': 1582, 'filtered_total': 55},
#  ('', '', 'Tanzania'): {'num_total': 1922, 'filtered_total': 61},
#  ('', '', 'Thailand'): {'num_total': 6640, 'filtered_total': 171},
#  ('', '', 'The Bahamas'): {'num_total': 1585, 'filtered_total': 96},
#  ('', '', 'The Gambia'): {'num_total': 31, 'filtered_total': 1},
#  ('', '', 'Trinidad and Tobago'): {'num_total': 5365, 'filtered_total': 236},
#  ('', '', 'Tunisia'): {'num_total': 763, 'filtered_total': 19},
#  ('', '', 'Turkey'): {'num_total': 1559, 'filtered_total': 13},
#  ('', '', 'Turks and Caicos Islands'): {'num_total': 184, 'filtered_total': 8},
#  ('', '', 'United Arab Emirates'): {'num_total': 1354, 'filtered_total': 75},
#  ('', '', 'United Kingdom'): {'num_total': 54885, 'filtered_total': 4047},
#  ('', '', 'United States'): {'num_total': 282776, 'filtered_total': 23492},
#  ('', '', 'Uruguay'): {'num_total': 8266, 'filtered_total': 402},
#  ('', '', 'Venezuela'): {'num_total': 318827, 'filtered_total': 9347},
#  ('', '', 'Vietnam'): {'num_total': 1767, 'filtered_total': 79},
#  ('', '', 'Yemen'): {'num_total': 352, 'filtered_total': 26},
#  ('', '', 'Zimbabwe'): {'num_total': 1743, 'filtered_total': 56},
#  ('', 'Aceh', 'Indonesia'): {'num_total': 906, 'filtered_total': 33},
#  ('', 'Aguascalientes', 'Mexico'): {'num_total': 129, 'filtered_total': 14},
#  ('', 'Alabama', 'United States'): {'num_total': 4656, 'filtered_total': 219},
#  ('', 'Alaska', 'United States'): {'num_total': 1412, 'filtered_total': 47},
#  ('', 'Alberta', 'Canada'): {'num_total': 1827, 'filtered_total': 131},
#  ('', 'Andalusia', 'Spain'): {'num_total': 241, 'filtered_total': 13},
#  ('', 'Aquitaine', 'France'): {'num_total': 339, 'filtered_total': 1},
#  ('', 'Arizona', 'United States'): {'num_total': 12490, 'filtered_total': 998},
#  ('', 'Arkansas', 'United States'): {'num_total': 3902, 'filtered_total': 188},
#  ('', 'Asunción', 'Paraguay'): {'num_total': 3069, 'filtered_total': 86},
#  ('', 'Balearic Islands', 'Spain'): {'num_total': 320, 'filtered_total': 14},
#  ('', 'Bali', 'Indonesia'): {'num_total': 897, 'filtered_total': 6},
#  ('', 'British Columbia', 'Canada'): {'num_total': 1445,
#   'filtered_total': 100},
#  ('', 'California', 'United States'): {'num_total': 80613,
#   'filtered_total': 4594},
#  ('', 'Catalonia', 'Spain'): {'num_total': 2088, 'filtered_total': 18},
#  ('', 'Chiapas', 'Mexico'): {'num_total': 2235, 'filtered_total': 71},
#  ('', 'Coahuila de Zaragoza', 'Mexico'): {'num_total': 475,
#   'filtered_total': 17},
#  ('', 'Colorado', 'United States'): {'num_total': 7888, 'filtered_total': 294},
#  ('', 'Connecticut', 'United States'): {'num_total': 11776,
#   'filtered_total': 778},
#  ('', 'Delaware', 'United States'): {'num_total': 2478, 'filtered_total': 83},
#  ('', 'Delhi', 'India'): {'num_total': 4396, 'filtered_total': 264},
#  ('', 'District of Columbia', 'United States'): {'num_total': 509,
#   'filtered_total': 29},
#  ('', 'England', 'United Kingdom'): {'num_total': 17190,
#   'filtered_total': 928},
#  ('', 'Espirito Santo', 'Brazil'): {'num_total': 2531, 'filtered_total': 83},
#  ('', 'Florida', 'United States'): {'num_total': 83447,
#   'filtered_total': 6091},
#  ('', 'Georgia', 'United States'): {'num_total': 13378, 'filtered_total': 762},
#  ('', 'Guam', 'United States'): {'num_total': 675, 'filtered_total': 31},
#  ('', 'Hawaii', 'United States'): {'num_total': 4265, 'filtered_total': 268},
#  ('', 'Himachal Pradesh', 'India'): {'num_total': 64, 'filtered_total': 5},
#  ('', 'Idaho', 'United States'): {'num_total': 7931, 'filtered_total': 236},
#  ('', 'Illinois', 'United States'): {'num_total': 12121,
#   'filtered_total': 780},
#  ('', 'Indiana', 'United States'): {'num_total': 4867, 'filtered_total': 232},
#  ('', 'Iowa', 'United States'): {'num_total': 4175, 'filtered_total': 213},
#  ('', 'Isle of Man', 'United Kingdom'): {'num_total': 102,
#   'filtered_total': 4},
#  ('', 'Jalisco', 'Mexico'): {'num_total': 502, 'filtered_total': 30},
#  ('', 'Jawa Timur', 'Indonesia'): {'num_total': 89},
#  ('', 'Kaduna', 'Nigeria'): {'num_total': 486, 'filtered_total': 12},
#  ('', 'Kampala', 'Uganda'): {'num_total': 3658, 'filtered_total': 159},
#  ('', 'Kansas', 'United States'): {'num_total': 2923, 'filtered_total': 194},
#  ('', 'Kentucky', 'United States'): {'num_total': 5346, 'filtered_total': 322},
#  ('', 'Kerala', 'India'): {'num_total': 537, 'filtered_total': 12},
#  ('', 'La Altagracia', 'Dominican Republic'): {'num_total': 823,
#   'filtered_total': 27},
#  ('', 'La Paz', 'Bolivia'): {'num_total': 1987, 'filtered_total': 127},
#  ('', 'Louisiana', 'United States'): {'num_total': 9866,
#   'filtered_total': 475},
#  ('', 'Maharashtra', 'India'): {'num_total': 362, 'filtered_total': 13},
#  ('', 'Maine', 'United States'): {'num_total': 4280, 'filtered_total': 300},
#  ('', 'Manitoba', 'Canada'): {'num_total': 285, 'filtered_total': 10},
#  ('', 'Maryland', 'United States'): {'num_total': 14747,
#   'filtered_total': 1124},
#  ('', 'Massachusetts', 'United States'): {'num_total': 11472,
#   'filtered_total': 580},
#  ('', 'Melaka', 'Malaysia'): {'num_total': 322, 'filtered_total': 2},
#  ('', 'Mexico', 'Mexico'): {'num_total': 740, 'filtered_total': 39},
#  ('', 'Michigan', 'United States'): {'num_total': 16044,
#   'filtered_total': 1122},
#  ('', 'Minas Gerais', 'Brazil'): {'num_total': 19156, 'filtered_total': 181},
#  ('', 'Minnesota', 'United States'): {'num_total': 8938,
#   'filtered_total': 407},
#  ('', 'Mississippi', 'United States'): {'num_total': 2927,
#   'filtered_total': 97},
#  ('', 'Missouri', 'United States'): {'num_total': 6468, 'filtered_total': 375},
#  ('', 'Montana', 'United States'): {'num_total': 2277, 'filtered_total': 97},
#  ('', 'Nevada', 'United States'): {'num_total': 5708, 'filtered_total': 283},
#  ('', 'New Brunswick', 'Canada'): {'num_total': 267, 'filtered_total': 10},
#  ('', 'New Hampshire', 'United States'): {'num_total': 3595,
#   'filtered_total': 283},
#  ('', 'New Jersey', 'United States'): {'num_total': 29495,
#   'filtered_total': 1575},
#  ('', 'New Mexico', 'United States'): {'num_total': 1772,
#   'filtered_total': 158},
#  ('', 'New South Wales', 'Australia'): {'num_total': 486,
#   'filtered_total': 22},
#  ('', 'New York', 'United States'): {'num_total': 91737,
#   'filtered_total': 7201},
#  ('', 'North Carolina', 'United States'): {'num_total': 12098,
#   'filtered_total': 884},
#  ('', 'North Dakota', 'United States'): {'num_total': 958,
#   'filtered_total': 53},
#  ('', 'North Sulawesi', 'Indonesia'): {'num_total': 14, 'filtered_total': 2},
#  ('', 'Oaxaca', 'Mexico'): {'num_total': 2708, 'filtered_total': 57},
#  ('', 'Ohio', 'United States'): {'num_total': 18752, 'filtered_total': 913},
#  ('', 'Oklahoma', 'United States'): {'num_total': 3470, 'filtered_total': 224},
#  ('', 'Ontario', 'Canada'): {'num_total': 3784, 'filtered_total': 172},
#  ('', 'Oregon', 'United States'): {'num_total': 7135, 'filtered_total': 299},
#  ('', 'Pahang', 'Malaysia'): {'num_total': 238},
#  ('', 'Penang', 'Malaysia'): {'num_total': 759, 'filtered_total': 13},
#  ('', 'Pennsylvania', 'United States'): {'num_total': 37149,
#   'filtered_total': 1681},
#  ('', 'Pernambuco', 'Brazil'): {'num_total': 1532, 'filtered_total': 34},
#  ('', 'Pichincha', 'Ecuador'): {'num_total': 7047, 'filtered_total': 186},
#  ('', 'Prague', 'Czech Republic'): {'num_total': 603, 'filtered_total': 24},
#  ('', 'Puerto Rico', 'United States'): {'num_total': 31251,
#   'filtered_total': 1266},
#  ('', 'Punjab', 'India'): {'num_total': 215, 'filtered_total': 13},
#  ('', 'Punjab', 'Pakistan'): {'num_total': 1378, 'filtered_total': 172},
#  ('', 'Queensland', 'Australia'): {'num_total': 1335, 'filtered_total': 116},
#  ('', 'Rhode Island', 'United States'): {'num_total': 1912,
#   'filtered_total': 68},
#  ('', 'Sabah', 'Malaysia'): {'num_total': 694, 'filtered_total': 1},
#  ('', 'Salta', 'Argentina'): {'num_total': 5811, 'filtered_total': 415},
#  ('', 'San Jose', 'Costa Rica'): {'num_total': 2465, 'filtered_total': 128},
#  ('', 'Santa Catarina', 'Brazil'): {'num_total': 2688, 'filtered_total': 33},
#  ('', 'Sarawak', 'Malaysia'): {'num_total': 683, 'filtered_total': 42},
#  ('', 'Scotland', 'United Kingdom'): {'num_total': 2430, 'filtered_total': 80},
#  ('', 'Sindh', 'Pakistan'): {'num_total': 110, 'filtered_total': 2},
#  ('', 'Sonora', 'Mexico'): {'num_total': 259, 'filtered_total': 10},
#  ('', 'South Carolina', 'United States'): {'num_total': 12833,
#   'filtered_total': 499},
#  ('', 'South Dakota', 'United States'): {'num_total': 817,
#   'filtered_total': 70},
#  ('', 'Tamil Nadu', 'India'): {'num_total': 156, 'filtered_total': 1},
#  ('', 'Tennessee', 'United States'): {'num_total': 7032,
#   'filtered_total': 566},
#  ('', 'Texas', 'United States'): {'num_total': 33781, 'filtered_total': 2586},
#  ('', 'US Virgin Islands', 'United States'): {'num_total': 1042,
#   'filtered_total': 80},
#  ('', 'Utah', 'United States'): {'num_total': 7136, 'filtered_total': 214},
#  ('', 'Valparaiso', 'Chile'): {'num_total': 858, 'filtered_total': 40},
#  ('', 'Vermont', 'United States'): {'num_total': 1764, 'filtered_total': 89},
#  ('', 'Victoria', 'Australia'): {'num_total': 519, 'filtered_total': 16},
#  ('', 'Virginia', 'United States'): {'num_total': 18395,
#   'filtered_total': 1221},
#  ('', 'Wales', 'United Kingdom'): {'num_total': 1722, 'filtered_total': 109},
#  ('', 'Washington', 'United States'): {'num_total': 700, 'filtered_total': 54},
#  ('', 'Wellington', 'New Zealand'): {'num_total': 228, 'filtered_total': 2},
#  ('', 'West Java', 'Indonesia'): {'num_total': 560},
#  ('', 'West Virginia', 'United States'): {'num_total': 1882,
#   'filtered_total': 78},
#  ('', 'Wisconsin', 'United States'): {'num_total': 16658,
#   'filtered_total': 1071},
#  ('', 'Wyoming', 'United States'): {'num_total': 1516, 'filtered_total': 55},
#  ('Abilene', 'Texas', 'United States'): {'num_total': 358,
#   'filtered_total': 38},
#  ('Abingdon', 'Maryland', 'United States'): {'num_total': 22,
#   'filtered_total': 1},
#  ('Abu Dhabi', '', 'United Arab Emirates'): {'num_total': 1067,
#   'filtered_total': 70},
#  ('Abuja', 'Federal Capital Territory', 'Nigeria'): {'num_total': 11455,
#   'filtered_total': 889},
#  ('Accra', 'Greater Accra', 'Ghana'): {'num_total': 3449,
#   'filtered_total': 173},
#  ('Addis Ababa', 'Addis Ababa', 'Ethiopia'): {'num_total': 388,
#   'filtered_total': 20},
#  ('Adelaide', 'South Australia', 'Australia'): {'num_total': 1509,
#   'filtered_total': 81},
#  ('Agawam', 'Massachusetts', 'United States'): {'num_total': 65,
#   'filtered_total': 7},
#  ('Aguascalientes', 'Aguascalientes', 'Mexico'): {'num_total': 145,
#   'filtered_total': 10},
#  ('Aiken', 'South Carolina', 'United States'): {'num_total': 101,
#   'filtered_total': 11},
#  ('Akron', 'Ohio', 'United States'): {'num_total': 1021, 'filtered_total': 53},
#  ('Albany', 'New York', 'United States'): {'num_total': 1719,
#   'filtered_total': 120},
#  ('Albuquerque', 'New Mexico', 'United States'): {'num_total': 3613,
#   'filtered_total': 243},
#  ('Alexandria', 'Al Iskandariyah', 'Egypt'): {'num_total': 1111,
#   'filtered_total': 13},
#  ('Alexandria', 'Virginia', 'United States'): {'num_total': 4722,
#   'filtered_total': 364},
#  ('Allendale', 'Michigan', 'United States'): {'num_total': 37,
#   'filtered_total': 3},
#  ('Allentown', 'Pennsylvania', 'United States'): {'num_total': 528,
#   'filtered_total': 38},
#  ('Alpharetta', 'Georgia', 'United States'): {'num_total': 1396,
#   'filtered_total': 168},
#  ('Amarillo', 'Texas', 'United States'): {'num_total': 589,
#   'filtered_total': 46},
#  ('Anaheim', 'California', 'United States'): {'num_total': 625,
#   'filtered_total': 34},
#  ('Anchorage', 'Alaska', 'United States'): {'num_total': 1493,
#   'filtered_total': 76},
#  ('Angleton', 'Texas', 'United States'): {'num_total': 54,
#   'filtered_total': 4},
#  ('Ann Arbor', 'Michigan', 'United States'): {'num_total': 2474,
#   'filtered_total': 111},
#  ('Annandale', 'Virginia', 'United States'): {'num_total': 395,
#   'filtered_total': 30},
#  ('Annapolis', 'Maryland', 'United States'): {'num_total': 778,
#   'filtered_total': 61},
#  ('Ansonia', 'Connecticut', 'United States'): {'num_total': 17},
#  ('Antioch', 'Tennessee', 'United States'): {'num_total': 282,
#   'filtered_total': 2},
#  ('Apopka', 'Florida', 'United States'): {'num_total': 75,
#   'filtered_total': 10},
#  ('Appleton', 'Wisconsin', 'United States'): {'num_total': 1356,
#   'filtered_total': 217},
#  ('Ardmore', 'Oklahoma', 'United States'): {'num_total': 15,
#   'filtered_total': 3},
#  ('Arlington', 'Texas', 'United States'): {'num_total': 1722,
#   'filtered_total': 162},
#  ('Arlington', 'Virginia', 'United States'): {'num_total': 3373,
#   'filtered_total': 223},
#  ('Arlington Heights', 'Illinois', 'United States'): {'num_total': 125,
#   'filtered_total': 10},
#  ('Arvada', 'Colorado', 'United States'): {'num_total': 158,
#   'filtered_total': 8},
#  ('Ashburn', 'Georgia', 'United States'): {'num_total': 11,
#   'filtered_total': 2},
#  ('Asheville', 'North Carolina', 'United States'): {'num_total': 826,
#   'filtered_total': 56},
#  ('Ashland', 'Oregon', 'United States'): {'num_total': 128,
#   'filtered_total': 14},
#  ('Aspen', 'Colorado', 'United States'): {'num_total': 146,
#   'filtered_total': 12},
#  ('Athens', 'Alabama', 'United States'): {'num_total': 116,
#   'filtered_total': 10},
#  ('Athens', 'Georgia', 'United States'): {'num_total': 1638,
#   'filtered_total': 67},
#  ('Athens', 'Ohio', 'United States'): {'num_total': 381, 'filtered_total': 14},
#  ('Atlanta', 'Georgia', 'United States'): {'num_total': 42369,
#   'filtered_total': 3812},
#  ('Atlantic City', 'New Jersey', 'United States'): {'num_total': 220,
#   'filtered_total': 9},
#  ('Auburn', 'Alabama', 'United States'): {'num_total': 289,
#   'filtered_total': 8},
#  ('Auckland', 'Auckland', 'New Zealand'): {'num_total': 1397,
#   'filtered_total': 89},
#  ('Augusta', 'Georgia', 'United States'): {'num_total': 863,
#   'filtered_total': 70},
#  ('Augusta', 'Maine', 'United States'): {'num_total': 284,
#   'filtered_total': 25},
#  ('Aurora', 'Colorado', 'United States'): {'num_total': 659,
#   'filtered_total': 32},
#  ('Aurora', 'Illinois', 'United States'): {'num_total': 163,
#   'filtered_total': 3},
#  ('Austin', 'Texas', 'United States'): {'num_total': 19355,
#   'filtered_total': 1332},
#  ('Avalon', 'California', 'United States'): {'num_total': 42},
#  ('Bainbridge Island', 'Washington', 'United States'): {'num_total': 201,
#   'filtered_total': 1},
#  ('Baltimore', 'Maryland', 'United States'): {'num_total': 15447,
#   'filtered_total': 908},
#  ('Bandung', 'West Java', 'Indonesia'): {'num_total': 8927,
#   'filtered_total': 131},
#  ('Bang Phli', 'Samut Prakan', 'Thailand'): {'num_total': 317,
#   'filtered_total': 3},
#  ('Bangalore', 'Karnataka', 'India'): {'num_total': 7130,
#   'filtered_total': 469},
#  ('Bangkok', 'Bangkok', 'Thailand'): {'num_total': 5748,
#   'filtered_total': 119},
#  ('Bangor', 'Maine', 'United States'): {'num_total': 200,
#   'filtered_total': 13},
#  ('Banjarmasin', 'South Kalimantan', 'Indonesia'): {'num_total': 722,
#   'filtered_total': 8},
#  ('Barberton', 'Ohio', 'United States'): {'num_total': 34,
#   'filtered_total': 1},
#  ('Barboursville', 'West Virginia', 'United States'): {'num_total': 11,
#   'filtered_total': 1},
#  ('Barcelona', 'Catalonia', 'Spain'): {'num_total': 11638,
#   'filtered_total': 465},
#  ('Barranquilla', 'Atlantico', 'Colombia'): {'num_total': 5031,
#   'filtered_total': 171},
#  ('Baton Rouge', 'Louisiana', 'United States'): {'num_total': 2203,
#   'filtered_total': 141},
#  ('Bauru', 'Sao Paulo', 'Brazil'): {'num_total': 3095, 'filtered_total': 36},
#  ('Bay Shore', 'New York', 'United States'): {'num_total': 105,
#   'filtered_total': 18},
#  ('Bayamón', 'Puerto Rico', 'United States'): {'num_total': 1040,
#   'filtered_total': 81},
#  ('Beacon', 'New York', 'United States'): {'num_total': 41,
#   'filtered_total': 2},
#  ('Beaufort', 'South Carolina', 'United States'): {'num_total': 176,
#   'filtered_total': 34},
#  ('Beaumont', 'Texas', 'United States'): {'num_total': 289,
#   'filtered_total': 28},
#  ('Beaverton', 'Oregon', 'United States'): {'num_total': 242,
#   'filtered_total': 19},
#  ('Beckley', 'West Virginia', 'United States'): {'num_total': 319,
#   'filtered_total': 55},
#  ('Beijing', 'Beijing', 'China'): {'num_total': 803, 'filtered_total': 45},
#  ('Belleville', 'Ontario', 'Canada'): {'num_total': 76, 'filtered_total': 4},
#  ('Bellevue', 'Washington', 'United States'): {'num_total': 558,
#   'filtered_total': 51},
#  ('Bellingham', 'Washington', 'United States'): {'num_total': 414,
#   'filtered_total': 27},
#  ('Bemidji', 'Minnesota', 'United States'): {'num_total': 11,
#   'filtered_total': 1},
#  ('Bensalem', 'Pennsylvania', 'United States'): {'num_total': 48,
#   'filtered_total': 2},
#  ('Benton', 'Pennsylvania', 'United States'): {'num_total': 389,
#   'filtered_total': 28},
#  ('Bentonville', 'Arkansas', 'United States'): {'num_total': 79,
#   'filtered_total': 7},
#  ('Berkeley', 'California', 'United States'): {'num_total': 1774,
#   'filtered_total': 90},
#  ('Berlin', 'Berlin', 'Germany'): {'num_total': 5888, 'filtered_total': 137},
#  ('Bethel', 'Vermont', 'United States'): {'num_total': 13,
#   'filtered_total': 1},
#  ('Bethesda', 'Maryland', 'United States'): {'num_total': 2460,
#   'filtered_total': 157},
#  ('Beverly Hills', 'California', 'United States'): {'num_total': 1698,
#   'filtered_total': 62},
#  ('Biloxi', 'Mississippi', 'United States'): {'num_total': 174,
#   'filtered_total': 25},
#  ('Binghamton', 'New York', 'United States'): {'num_total': 426,
#   'filtered_total': 22},
#  ('Birmingham', 'Alabama', 'United States'): {'num_total': 2804,
#   'filtered_total': 193},
#  ('Birmingham', 'Michigan', 'United States'): {'num_total': 141,
#   'filtered_total': 37},
#  ('Bismarck', 'North Dakota', 'United States'): {'num_total': 176,
#   'filtered_total': 17},
#  ('Blacksburg', 'Virginia', 'United States'): {'num_total': 391,
#   'filtered_total': 34},
#  ('Bloomington', 'Indiana', 'United States'): {'num_total': 846,
#   'filtered_total': 30},
#  ('Blumenau', 'Santa Catarina', 'Brazil'): {'num_total': 5032,
#   'filtered_total': 121},
#  ('Blythe', 'California', 'United States'): {'num_total': 160,
#   'filtered_total': 9},
#  ('Boca Raton', 'Florida', 'United States'): {'num_total': 2445,
#   'filtered_total': 145},
#  ('Bogota', 'Distrito Especial', 'Colombia'): {'num_total': 7639,
#   'filtered_total': 183},
#  ('Boise', 'Idaho', 'United States'): {'num_total': 2279,
#   'filtered_total': 153},
#  ('Bordeaux', 'Aquitaine', 'France'): {'num_total': 524, 'filtered_total': 4},
#  ('Boston', 'Massachusetts', 'United States'): {'num_total': 28149,
#   'filtered_total': 1549},
#  ('Boulder', 'Colorado', 'United States'): {'num_total': 1172,
#   'filtered_total': 91},
#  ('Bowie', 'Maryland', 'United States'): {'num_total': 280,
#   'filtered_total': 15},
#  ('Bowling Green', 'Kentucky', 'United States'): {'num_total': 292,
#   'filtered_total': 15},
#  ('Bowling Green', 'Ohio', 'United States'): {'num_total': 148,
#   'filtered_total': 12},
#  ('Boynton Beach', 'Florida', 'United States'): {'num_total': 358,
#   'filtered_total': 45},
#  ('Bradenton', 'Florida', 'United States'): {'num_total': 906,
#   'filtered_total': 117},
#  ('Brampton', 'Ontario', 'Canada'): {'num_total': 472, 'filtered_total': 20},
#  ('Brasilia', 'Distrito Federal', 'Brazil'): {'num_total': 7758,
#   'filtered_total': 230},
#  ('Brentwood', 'New York', 'United States'): {'num_total': 36,
#   'filtered_total': 1},
#  ('Brighton', 'England', 'United Kingdom'): {'num_total': 1275,
#   'filtered_total': 103},
#  ('Brighton', 'Massachusetts', 'United States'): {'num_total': 256,
#   'filtered_total': 18},
#  ('Brisbane', 'Queensland', 'Australia'): {'num_total': 7702,
#   'filtered_total': 374},
#  ('Bristol', 'England', 'United Kingdom'): {'num_total': 1542,
#   'filtered_total': 73},
#  ('Bristol', 'Tennessee', 'United States'): {'num_total': 242,
#   'filtered_total': 9},
#  ('Bristow', 'Virginia', 'United States'): {'num_total': 27,
#   'filtered_total': 2},
#  ('Brockton', 'Massachusetts', 'United States'): {'num_total': 67,
#   'filtered_total': 9},
#  ('Bronx', 'New York', 'United States'): {'num_total': 3779,
#   'filtered_total': 274},
#  ('Brookings', 'South Dakota', 'United States'): {'num_total': 87,
#   'filtered_total': 3},
#  ('Brooklyn', 'New York', 'United States'): {'num_total': 16269,
#   'filtered_total': 1088},
#  ('Brownsville', 'California', 'United States'): {'num_total': 12,
#   'filtered_total': 2},
#  ('Brownsville', 'Texas', 'United States'): {'num_total': 408,
#   'filtered_total': 23},
#  ('Brussels', 'Brussels-Capital Region', 'Belgium'): {'num_total': 5228,
#   'filtered_total': 168},
#  ('Bucharest', '', 'Romania'): {'num_total': 1464, 'filtered_total': 21},
#  ('Buckeye', 'Arizona', 'United States'): {'num_total': 33,
#   'filtered_total': 3},
#  ('Budapest', '', 'Hungary'): {'num_total': 483, 'filtered_total': 11},
#  ('Buenos Aires',
#   'Autonomous City of Buenos Aires',
#   'Argentina'): {'num_total': 25937, 'filtered_total': 1235},
#  ('Buffalo', 'New York', 'United States'): {'num_total': 3589,
#   'filtered_total': 193},
#  ('Burbank', 'California', 'United States'): {'num_total': 951,
#   'filtered_total': 50},
#  ('Burlington', 'Vermont', 'United States'): {'num_total': 659,
#   'filtered_total': 44},
#  ('Burnsville', 'Minnesota', 'United States'): {'num_total': 62,
#   'filtered_total': 5},
#  ('Cairo', 'Al Qahirah', 'Egypt'): {'num_total': 2722, 'filtered_total': 66},
#  ('Calabasas', 'California', 'United States'): {'num_total': 231,
#   'filtered_total': 4},
#  ('Calgary', 'Alberta', 'Canada'): {'num_total': 4097, 'filtered_total': 266},
#  ('Camarillo', 'California', 'United States'): {'num_total': 78,
#   'filtered_total': 4},
#  ('Cambridge', 'England', 'United Kingdom'): {'num_total': 1572,
#   'filtered_total': 57},
#  ('Cambridge', 'Massachusetts', 'United States'): {'num_total': 3941,
#   'filtered_total': 205},
#  ('Camden', 'New Jersey', 'United States'): {'num_total': 132,
#   'filtered_total': 2},
#  ('Campeche', 'Campeche', 'Mexico'): {'num_total': 2651, 'filtered_total': 82},
#  ('Campina Grande', 'Paraiba', 'Brazil'): {'num_total': 3944,
#   'filtered_total': 182},
#  ('Campinas', 'Sao Paulo', 'Brazil'): {'num_total': 3413,
#   'filtered_total': 23},
#  ('Canberra', 'Australian Capital Territory', 'Australia'): {'num_total': 1540,
#   'filtered_total': 77},
#  ('Cape Coral', 'Florida', 'United States'): {'num_total': 348,
#   'filtered_total': 27},
#  ('Cape Girardeau', 'Missouri', 'United States'): {'num_total': 217,
#   'filtered_total': 45},
#  ('Cape Town', 'Western Cape', 'South Africa'): {'num_total': 5186,
#   'filtered_total': 196},
#  ('Capitol', 'Montana', 'United States'): {'num_total': 242,
#   'filtered_total': 2},
#  ('Caracas', 'Distrito Federal', 'Venezuela'): {'num_total': 87385,
#   'filtered_total': 2576},
#  ('Cardiff', 'Wales', 'United Kingdom'): {'num_total': 1368,
#   'filtered_total': 56},
#  ('Carlsbad', 'California', 'United States'): {'num_total': 329,
#   'filtered_total': 26},
#  ('Carrboro', 'North Carolina', 'United States'): {'num_total': 181,
#   'filtered_total': 10},
#  ('Cary', 'North Carolina', 'United States'): {'num_total': 468,
#   'filtered_total': 36},
#  ('Casa Grande', 'Arizona', 'United States'): {'num_total': 90,
#   'filtered_total': 6},
#  ('Casablanca', 'Greater Casablanca', 'Morocco'): {'num_total': 603,
#   'filtered_total': 11},
#  ('Cascadia', 'Oregon', 'United States'): {'num_total': 217,
#   'filtered_total': 13},
#  ('Casper', 'Wyoming', 'United States'): {'num_total': 69,
#   'filtered_total': 14},
#  ('Cebu', 'Central Visayas', 'Philippines'): {'num_total': 587,
#   'filtered_total': 17},
#  ('Cedar Rapids', 'Iowa', 'United States'): {'num_total': 380,
#   'filtered_total': 21},
#  ('Celebration', 'Florida', 'United States'): {'num_total': 308,
#   'filtered_total': 34},
#  ('Centennial', 'Colorado', 'United States'): {'num_total': 165,
#   'filtered_total': 12},
#  ('Centerville', 'Ohio', 'United States'): {'num_total': 51,
#   'filtered_total': 3},
#  ('Centreville', 'Virginia', 'United States'): {'num_total': 225,
#   'filtered_total': 18},
#  ('Chandigarh', 'Chandigarh', 'India'): {'num_total': 1935,
#   'filtered_total': 168},
#  ('Chandler', 'Arizona', 'United States'): {'num_total': 503,
#   'filtered_total': 36},
#  ('Chapel Hill', 'North Carolina', 'United States'): {'num_total': 2562,
#   'filtered_total': 110},
#  ('Chapin', 'South Carolina', 'United States'): {'num_total': 26,
#   'filtered_total': 4},
#  ('Charleston', 'South Carolina', 'United States'): {'num_total': 2918,
#   'filtered_total': 354},
#  ('Charleston', 'West Virginia', 'United States'): {'num_total': 768,
#   'filtered_total': 99},
#  ('Charlotte', 'North Carolina', 'United States'): {'num_total': 7256,
#   'filtered_total': 658},
#  ('Charlottesville', 'Virginia', 'United States'): {'num_total': 1343,
#   'filtered_total': 103},
#  ('Chattanooga', 'Tennessee', 'United States'): {'num_total': 1929,
#   'filtered_total': 143},
#  ('Cheektowaga', 'New York', 'United States'): {'num_total': 117,
#   'filtered_total': 2},
#  ('Chennai', 'Tamil Nadu', 'India'): {'num_total': 4479,
#   'filtered_total': 333},
#  ('Cheras (Kuala Lumpur)',
#   'Wilayah Persekutuan',
#   'Malaysia'): {'num_total': 20, 'filtered_total': 1},
#  ('Chesterfield', 'Missouri', 'United States'): {'num_total': 261,
#   'filtered_total': 28},
#  ('Cheyenne', 'Wyoming', 'United States'): {'num_total': 193,
#   'filtered_total': 14},
#  ('Chiang Mai', 'Roi Et', 'Thailand'): {'num_total': 443,
#   'filtered_total': 14},
#  ('Chicago', 'Illinois', 'United States'): {'num_total': 35934,
#   'filtered_total': 1970},
#  ('Chicago Heights', 'Illinois', 'United States'): {'num_total': 23,
#   'filtered_total': 1},
#  ('Chico', 'California', 'United States'): {'num_total': 300,
#   'filtered_total': 13},
#  ('Chicopee', 'Massachusetts', 'United States'): {'num_total': 166,
#   'filtered_total': 21},
#  ('Christchurch', 'Canterbury', 'New Zealand'): {'num_total': 309,
#   'filtered_total': 14},
#  ('Christiansburg', 'Virginia', 'United States'): {'num_total': 28,
#   'filtered_total': 3},
#  ('Cincinnati', 'Ohio', 'United States'): {'num_total': 4803,
#   'filtered_total': 393},
#  ('City', 'State', 'Country'): {'num_total': 86778},
#  ('Claremont', 'California', 'United States'): {'num_total': 89,
#   'filtered_total': 9},
#  ('Clarksville', 'Tennessee', 'United States'): {'num_total': 301,
#   'filtered_total': 25},
#  ('Clearwater', 'Florida', 'United States'): {'num_total': 1373,
#   'filtered_total': 66},
#  ('Clermont', 'Florida', 'United States'): {'num_total': 70,
#   'filtered_total': 7},
#  ('Cleveland', 'Ohio', 'United States'): {'num_total': 7261,
#   'filtered_total': 334},
#  ('Clovis', 'California', 'United States'): {'num_total': 160,
#   'filtered_total': 18},
#  ('Coatesville', 'Pennsylvania', 'United States'): {'num_total': 25},
#  ('Colima', 'Colima', 'Mexico'): {'num_total': 1753, 'filtered_total': 51},
#  ('College Station', 'Texas', 'United States'): {'num_total': 1027,
#   'filtered_total': 66},
#  ('Colonia Mariano Roque Alonso', 'Central', 'Paraguay'): {'num_total': 25,
#   'filtered_total': 1},
#  ('Colorado Springs', 'Colorado', 'United States'): {'num_total': 2463,
#   'filtered_total': 115},
#  ('Columbia', 'Missouri', 'United States'): {'num_total': 1120,
#   'filtered_total': 76},
#  ('Columbia', 'South Carolina', 'United States'): {'num_total': 2111,
#   'filtered_total': 171},
#  ('Columbus', 'Georgia', 'United States'): {'num_total': 508,
#   'filtered_total': 68},
#  ('Columbus', 'Indiana', 'United States'): {'num_total': 232,
#   'filtered_total': 30},
#  ('Columbus', 'Ohio', 'United States'): {'num_total': 5951,
#   'filtered_total': 324},
#  ('Compton', 'California', 'United States'): {'num_total': 1361,
#   'filtered_total': 232},
#  ('Concord', 'New Hampshire', 'United States'): {'num_total': 746,
#   'filtered_total': 108},
#  ('Conneaut', 'Ohio', 'United States'): {'num_total': 41, 'filtered_total': 3},
#  ('Conroe', 'Texas', 'United States'): {'num_total': 183, 'filtered_total': 8},
#  ('Conway', 'South Carolina', 'United States'): {'num_total': 53,
#   'filtered_total': 3},
#  ('Coral Gables', 'Florida', 'United States'): {'num_total': 1652,
#   'filtered_total': 243},
#  ('Coral Springs', 'Florida', 'United States'): {'num_total': 336,
#   'filtered_total': 19},
#  ('Cordele', 'Georgia', 'United States'): {'num_total': 173,
#   'filtered_total': 28},
#  ('Cordoba', '', 'Argentina'): {'num_total': 731, 'filtered_total': 52},
#  ('Cork', '', 'Ireland'): {'num_total': 879, 'filtered_total': 36},
#  ('Cornelius', 'North Carolina', 'United States'): {'num_total': 291},
#  ('Corona', 'California', 'United States'): {'num_total': 560,
#   'filtered_total': 50},
#  ('Coronado', 'California', 'United States'): {'num_total': 395,
#   'filtered_total': 70},
#  ('Corpus Christi', 'Texas', 'United States'): {'num_total': 1200,
#   'filtered_total': 111},
#  ('Cupertino', 'California', 'United States'): {'num_total': 1048,
#   'filtered_total': 63},
#  ('Curitiba', 'Parana', 'Brazil'): {'num_total': 15273, 'filtered_total': 204},
#  ('Cuyahoga Falls', 'Ohio', 'United States'): {'num_total': 268,
#   'filtered_total': 9},
#  ('Cyberjaya', 'Selangor', 'Malaysia'): {'num_total': 71, 'filtered_total': 1},
#  ('Cypress', 'Texas', 'United States'): {'num_total': 145,
#   'filtered_total': 5},
#  ('Dakar', 'Dakar', 'Senegal'): {'num_total': 379, 'filtered_total': 3},
#  ('Dallas', 'Pennsylvania', 'United States'): {'num_total': 12,
#   'filtered_total': 1},
#  ('Dallas', 'Texas', 'United States'): {'num_total': 19062,
#   'filtered_total': 1275},
#  ('Daly City', 'California', 'United States'): {'num_total': 691,
#   'filtered_total': 55},
#  ('Danville', 'California', 'United States'): {'num_total': 75,
#   'filtered_total': 3},
#  ('Dar es Salaam', 'Dar es Salaam', 'Tanzania'): {'num_total': 1082,
#   'filtered_total': 34},
#  ('Davao City', 'Davao Region', 'Philippines'): {'num_total': 349,
#   'filtered_total': 19},
#  ('Davenport', 'Florida', 'United States'): {'num_total': 66,
#   'filtered_total': 1},
#  ('Davis', 'California', 'United States'): {'num_total': 999,
#   'filtered_total': 84},
#  ('Dayton', 'Ohio', 'United States'): {'num_total': 1473,
#   'filtered_total': 114},
#  ('Daytona Beach', 'Florida', 'United States'): {'num_total': 624,
#   'filtered_total': 63},
#  ('Death Valley', 'California', 'United States'): {'num_total': 42},
#  ('Decatur', 'Illinois', 'United States'): {'num_total': 75,
#   'filtered_total': 4},
#  ('Dedham', 'Massachusetts', 'United States'): {'num_total': 443,
#   'filtered_total': 35},
#  ('Delhi', 'Madhya Pradesh', 'India'): {'num_total': 11809,
#   'filtered_total': 693},
#  ('Delray Beach', 'Florida', 'United States'): {'num_total': 1058,
#   'filtered_total': 104},
#  ('Denham Springs', 'Louisiana', 'United States'): {'num_total': 49,
#   'filtered_total': 4},
#  ('Denton', 'Texas', 'United States'): {'num_total': 757,
#   'filtered_total': 35},
#  ('Denver', 'Colorado', 'United States'): {'num_total': 11830,
#   'filtered_total': 933},
#  ('Depok', 'D.I. Yogyakarta', 'Indonesia'): {'num_total': 3820,
#   'filtered_total': 43},
#  ('Derby', 'England', 'United Kingdom'): {'num_total': 97,
#   'filtered_total': 7},
#  ('Derry', 'New Hampshire', 'United States'): {'num_total': 39,
#   'filtered_total': 2},
#  ('Des Moines', 'Iowa', 'United States'): {'num_total': 1793,
#   'filtered_total': 107},
#  ('Des Plaines', 'Illinois', 'United States'): {'num_total': 255,
#   'filtered_total': 8},
#  ('Detroit', 'Michigan', 'United States'): {'num_total': 4542,
#   'filtered_total': 205},
#  ('Dhaka', 'Dhaka', 'Bangladesh'): {'num_total': 5498, 'filtered_total': 430},
#  ('Dinwiddie', 'Virginia', 'United States'): {'num_total': 11,
#   'filtered_total': 1},
#  ('Doha', 'Doha', 'Qatar'): {'num_total': 1300, 'filtered_total': 47},
#  ('Dorchester', 'Massachusetts', 'United States'): {'num_total': 34},
#  ('Doylestown', 'Pennsylvania', 'United States'): {'num_total': 202,
#   'filtered_total': 20},
#  ('Drexel Hill', 'Pennsylvania', 'United States'): {'num_total': 256,
#   'filtered_total': 36},
#  ('Dubai', 'Dubai', 'United Arab Emirates'): {'num_total': 4705,
#   'filtered_total': 231},
#  ('Dublin', '', 'Ireland'): {'num_total': 5224, 'filtered_total': 194},
#  ('Dugway', 'Utah', 'United States'): {'num_total': 446, 'filtered_total': 24},
#  ('Dunedin', 'Florida', 'United States'): {'num_total': 42,
#   'filtered_total': 7},
#  ('Dunwoody', 'Georgia', 'United States'): {'num_total': 167,
#   'filtered_total': 12},
#  ('Durham', 'North Carolina', 'United States'): {'num_total': 3260,
#   'filtered_total': 139},
#  ('East Haven', 'Connecticut', 'United States'): {'num_total': 75,
#   'filtered_total': 4},
#  ('Eau Claire', 'Wisconsin', 'United States'): {'num_total': 344,
#   'filtered_total': 9},
#  ('Edinburgh', 'Scotland', 'United Kingdom'): {'num_total': 2397,
#   'filtered_total': 115},
#  ('El Dorado Hills', 'California', 'United States'): {'num_total': 105,
#   'filtered_total': 4},
#  ('El Monte', 'California', 'United States'): {'num_total': 117,
#   'filtered_total': 10},
#  ('El Paso', 'Texas', 'United States'): {'num_total': 2156,
#   'filtered_total': 144},
#  ('Elgin', 'Arizona', 'United States'): {'num_total': 18},
#  ('Elkridge', 'Maryland', 'United States'): {'num_total': 408,
#   'filtered_total': 39},
#  ('Elmira', 'New York', 'United States'): {'num_total': 75,
#   'filtered_total': 2},
#  ('Elyria', 'Ohio', 'United States'): {'num_total': 69, 'filtered_total': 2},
#  ('Emfuleni', 'Gauteng', 'South Africa'): {'num_total': 272,
#   'filtered_total': 14},
#  ('Emporia', 'Kansas', 'United States'): {'num_total': 51,
#   'filtered_total': 1},
#  ('Encino', 'California', 'United States'): {'num_total': 386,
#   'filtered_total': 41},
#  ('Erie', 'Pennsylvania', 'United States'): {'num_total': 620,
#   'filtered_total': 54},
#  ('Escondido', 'California', 'United States'): {'num_total': 441,
#   'filtered_total': 16},
#  ('Ethekwini', 'Kwazulu Natal', 'South Africa'): {'num_total': 1144,
#   'filtered_total': 21},
#  ('Eunice', 'Louisiana', 'United States'): {'num_total': 54,
#   'filtered_total': 1},
#  ('Evanston', 'Illinois', 'United States'): {'num_total': 535,
#   'filtered_total': 41},
#  ('Evansville', 'Indiana', 'United States'): {'num_total': 578,
#   'filtered_total': 25},
#  ('Ewa Beach', 'Hawaii', 'United States'): {'num_total': 131,
#   'filtered_total': 14},
#  ('Fairbanks', 'Alaska', 'United States'): {'num_total': 182,
#   'filtered_total': 6},
#  ('Fairborn', 'Ohio', 'United States'): {'num_total': 24},
#  ('Fairfax', 'Virginia', 'United States'): {'num_total': 1121,
#   'filtered_total': 104},
#  ('Fairfield', 'Connecticut', 'United States'): {'num_total': 294,
#   'filtered_total': 25},
#  ('Fairport', 'New York', 'United States'): {'num_total': 40,
#   'filtered_total': 5},
#  ('Falls Church', 'Virginia', 'United States'): {'num_total': 392,
#   'filtered_total': 39},
#  ('Fargo', 'North Dakota', 'United States'): {'num_total': 592,
#   'filtered_total': 66},
#  ('Farmington', 'Missouri', 'United States'): {'num_total': 30},
#  ('Farmville', 'Virginia', 'United States'): {'num_total': 67,
#   'filtered_total': 5},
#  ('Flower Mound', 'Texas', 'United States'): {'num_total': 216,
#   'filtered_total': 13},
#  ('Folsom', 'California', 'United States'): {'num_total': 238,
#   'filtered_total': 7},
#  ('Forked River', 'New Jersey', 'United States'): {'num_total': 13},
#  ('Forks', 'Washington', 'United States'): {'num_total': 84,
#   'filtered_total': 2},
#  ('Fort Collins', 'Colorado', 'United States'): {'num_total': 521,
#   'filtered_total': 32},
#  ('Fort Lauderdale', 'Florida', 'United States'): {'num_total': 5301,
#   'filtered_total': 531},
#  ('Fort Myers', 'Florida', 'United States'): {'num_total': 1138,
#   'filtered_total': 125},
#  ('Fort Smith', 'Arkansas', 'United States'): {'num_total': 164,
#   'filtered_total': 14},
#  ('Fort Walton Beach', 'Florida', 'United States'): {'num_total': 186,
#   'filtered_total': 22},
#  ('Fort Wayne', 'Indiana', 'United States'): {'num_total': 674,
#   'filtered_total': 37},
#  ('Fort Worth', 'Texas', 'United States'): {'num_total': 3104,
#   'filtered_total': 191},
#  ('Fortaleza', 'Ceara', 'Brazil'): {'num_total': 5442, 'filtered_total': 185},
#  ('Frankfort', 'Kentucky', 'United States'): {'num_total': 426,
#   'filtered_total': 52},
#  ('Frederick', 'Maryland', 'United States'): {'num_total': 458,
#   'filtered_total': 20},
#  ('Fredericksburg', 'Virginia', 'United States'): {'num_total': 216,
#   'filtered_total': 21},
#  ('Freedom', 'California', 'United States'): {'num_total': 73,
#   'filtered_total': 1},
#  ('Fremont', 'California', 'United States'): {'num_total': 483,
#   'filtered_total': 12},
#  ('Fresno', 'California', 'United States'): {'num_total': 2051,
#   'filtered_total': 145},
#  ('Friendswood', 'Texas', 'United States'): {'num_total': 151,
#   'filtered_total': 12},
#  ('Fullerton', 'California', 'United States'): {'num_total': 138,
#   'filtered_total': 11},
#  ('Gainesville', 'Alabama', 'United States'): {'num_total': 57,
#   'filtered_total': 4},
#  ('Gainesville', 'Florida', 'United States'): {'num_total': 2690,
#   'filtered_total': 166},
#  ('Gainesville', 'Georgia', 'United States'): {'num_total': 370,
#   'filtered_total': 51},
#  ('Galesburg', 'Illinois', 'United States'): {'num_total': 48,
#   'filtered_total': 3},
#  ('Galveston', 'Texas', 'United States'): {'num_total': 566,
#   'filtered_total': 35},
#  ('Garden City', 'New York', 'United States'): {'num_total': 834,
#   'filtered_total': 98},
#  ('Garden Grove', 'California', 'United States'): {'num_total': 238,
#   'filtered_total': 21},
#  ('Garden Grove', 'Iowa', 'United States'): {'num_total': 11,
#   'filtered_total': 1},
#  ('Gatineau', 'Quebec', 'Canada'): {'num_total': 217, 'filtered_total': 18},
#  ('Geneva', 'Geneva', 'Switzerland'): {'num_total': 5147,
#   'filtered_total': 288},
#  ('Gilbert', 'Arizona', 'United States'): {'num_total': 710,
#   'filtered_total': 51},
#  ('Glasgow', 'Scotland', 'United Kingdom'): {'num_total': 3678,
#   'filtered_total': 122},
#  ('Glastonbury', 'Connecticut', 'United States'): {'num_total': 90,
#   'filtered_total': 6},
#  ('Glens Falls', 'New York', 'United States'): {'num_total': 30,
#   'filtered_total': 1},
#  ('Goldsboro', 'North Carolina', 'United States'): {'num_total': 34,
#   'filtered_total': 1},
#  ('Goodyear', 'Arizona', 'United States'): {'num_total': 395,
#   'filtered_total': 44},
#  ('Goose Creek', 'South Carolina', 'United States'): {'num_total': 59,
#   'filtered_total': 1},
#  ('Gotham', 'Wisconsin', 'United States'): {'num_total': 585,
#   'filtered_total': 14},
#  ('Grand Rapids', 'Michigan', 'United States'): {'num_total': 1711,
#   'filtered_total': 91},
#  ('Grapevine', 'Texas', 'United States'): {'num_total': 289,
#   'filtered_total': 7},
#  ('Great Falls', 'Montana', 'United States'): {'num_total': 88,
#   'filtered_total': 3},
#  ('Greeley', 'Colorado', 'United States'): {'num_total': 108,
#   'filtered_total': 5},
#  ('Green Bay', 'Wisconsin', 'United States'): {'num_total': 672,
#   'filtered_total': 58},
#  ('Greendale', 'Indiana', 'United States'): {'num_total': 6,
#   'filtered_total': 1},
#  ('Greenfield', 'Wisconsin', 'United States'): {'num_total': 26,
#   'filtered_total': 3},
#  ('Greensboro', 'North Carolina', 'United States'): {'num_total': 1130,
#   'filtered_total': 68},
#  ('Greenville', 'Alabama', 'United States'): {'num_total': 53,
#   'filtered_total': 2},
#  ('Greenville', 'North Carolina', 'United States'): {'num_total': 516,
#   'filtered_total': 26},
#  ('Greenville', 'South Carolina', 'United States'): {'num_total': 1055,
#   'filtered_total': 110},
#  ('Greenwich', 'Connecticut', 'United States'): {'num_total': 497,
#   'filtered_total': 27},
#  ('Greenwood', 'Indiana', 'United States'): {'num_total': 68,
#   'filtered_total': 4},
#  ('Gresham', 'Oregon', 'United States'): {'num_total': 82,
#   'filtered_total': 1},
#  ('Guadalajara', 'Jalisco', 'Mexico'): {'num_total': 8285,
#   'filtered_total': 255},
#  ('Guarulhos', 'Sao Paulo', 'Brazil'): {'num_total': 7111,
#   'filtered_total': 47},
#  ('Guatemala City', 'Guatemala', 'Guatemala'): {'num_total': 12371,
#   'filtered_total': 335},
#  ('Guayama', 'Puerto Rico', 'United States'): {'num_total': 304,
#   'filtered_total': 13},
#  ('Guayaquil', 'Guayas', 'Ecuador'): {'num_total': 12353,
#   'filtered_total': 334},
#  ('Guelph', 'Ontario', 'Canada'): {'num_total': 334, 'filtered_total': 37},
#  ('Gulf Shores', 'Alabama', 'United States'): {'num_total': 157,
#   'filtered_total': 5},
#  ('Gulfport', 'Florida', 'United States'): {'num_total': 199,
#   'filtered_total': 26},
#  ('Halifax', 'Nova Scotia', 'Canada'): {'num_total': 1381,
#   'filtered_total': 84},
#  ('Hamburg', 'Hamburg', 'Germany'): {'num_total': 2376, 'filtered_total': 119},
#  ('Hamilton', 'Ontario', 'Canada'): {'num_total': 1049, 'filtered_total': 55},
#  ('Hanoi', 'Ha Noi', 'Vietnam'): {'num_total': 579, 'filtered_total': 19},
#  ('Hanover', 'New Hampshire', 'United States'): {'num_total': 72,
#   'filtered_total': 4},
#  ('Harlingen', 'Texas', 'United States'): {'num_total': 163,
#   'filtered_total': 15},
#  ('Harrisburg', 'Pennsylvania', 'United States'): {'num_total': 1591,
#   'filtered_total': 127},
#  ('Harrisonburg', 'Virginia', 'United States'): {'num_total': 262,
#   'filtered_total': 11},
#  ('Harrogate', 'Tennessee', 'United States'): {'num_total': 361,
#   'filtered_total': 29},
#  ('Hartford', 'Connecticut', 'United States'): {'num_total': 1730,
#   'filtered_total': 117},
#  ('Hattiesburg', 'Mississippi', 'United States'): {'num_total': 288,
#   'filtered_total': 19},
#  ('Hayward', 'California', 'United States'): {'num_total': 160,
#   'filtered_total': 19},
#  ('Hazard', 'Kentucky', 'United States'): {'num_total': 49,
#   'filtered_total': 5},
#  ('Helsingfors', 'Uusimaa', 'Finland'): {'num_total': 1392,
#   'filtered_total': 43},
#  ('Henderson', 'Nevada', 'United States'): {'num_total': 679,
#   'filtered_total': 17},
#  ('Henderson', 'Tennessee', 'United States'): {'num_total': 7},
#  ('High Point', 'North Carolina', 'United States'): {'num_total': 214,
#   'filtered_total': 14},
#  ('Hillsboro', 'Oregon', 'United States'): {'num_total': 115,
#   'filtered_total': 6},
#  ('Holeby', 'Sjaelland', 'Denmark'): {'num_total': 1751, 'filtered_total': 20},
#  ('Holly Springs', 'North Carolina', 'United States'): {'num_total': 140,
#   'filtered_total': 8},
#  ('Hollywood', 'Alabama', 'United States'): {'num_total': 456,
#   'filtered_total': 17},
#  ('Hollywood', 'California', 'United States'): {'num_total': 1462,
#   'filtered_total': 76},
#  ('Hollywood', 'Florida', 'United States'): {'num_total': 1372,
#   'filtered_total': 127},
#  ('Hong Kong', 'Hong Kong Island', 'Hong Kong'): {'num_total': 3918,
#   'filtered_total': 268},
#  ('Honolulu', 'Hawaii', 'United States'): {'num_total': 3437,
#   'filtered_total': 276},
#  ('Hopewell', 'Virginia', 'United States'): {'num_total': 8,
#   'filtered_total': 1},
#  ('Horn Lake', 'Mississippi', 'United States'): {'num_total': 119,
#   'filtered_total': 13},
#  ('Horseheads', 'New York', 'United States'): {'num_total': 36,
#   'filtered_total': 1},
#  ('Houston', 'Texas', 'United States'): {'num_total': 27260,
#   'filtered_total': 1651},
#  ('Howell', 'New Jersey', 'United States'): {'num_total': 13,
#   'filtered_total': 4},
#  ('Hubbard', 'Ohio', 'United States'): {'num_total': 26},
#  ('Humacao', 'Puerto Rico', 'United States'): {'num_total': 328,
#   'filtered_total': 10},
#  ('Huntersville', 'North Carolina', 'United States'): {'num_total': 294,
#   'filtered_total': 27},
#  ('Huntsville', 'Alabama', 'United States'): {'num_total': 1053,
# ...
#   'filtered_total': 21},
#  ('Pearland', 'Texas', 'United States'): {'num_total': 544,
#   'filtered_total': 14},
#  ('Pembroke Pines', 'Florida', 'United States'): {'num_total': 477,
#   'filtered_total': 28},
#  ('Pensacola', 'Florida', 'United States'): {'num_total': 1032,
#   'filtered_total': 98},
#  ('Peoria', 'Illinois', 'United States'): {'num_total': 383,
#   'filtered_total': 24},
#  ('Perth', 'Western Australia', 'Australia'): {'num_total': 2033,
#   'filtered_total': 92},
#  ('Peru', 'Indiana', 'United States'): {'num_total': 8},
#  ('Petaling Jaya', 'Selangor', 'Malaysia'): {'num_total': 1675,
#   'filtered_total': 50},
#  ('Peterborough', 'England', 'United Kingdom'): {'num_total': 36,
#   'filtered_total': 2},
#  ('Petersburg', 'Virginia', 'United States'): {'num_total': 44,
#   'filtered_total': 3},
#  ('Philadelphia', 'Pennsylvania', 'United States'): {'num_total': 23805,
#   'filtered_total': 1664},
#  ('Phnom Penh', 'Phnum Penh', 'Cambodia'): {'num_total': 408,
#   'filtered_total': 27},
#  ('Phoenix', 'Arizona', 'United States'): {'num_total': 7653,
#   'filtered_total': 558},
#  ('Pine Bluff', 'Arkansas', 'United States'): {'num_total': 22,
#   'filtered_total': 1},
#  ('Piracicaba', 'Sao Paulo', 'Brazil'): {'num_total': 3281,
#   'filtered_total': 32},
#  ('Pittsburgh', 'Pennsylvania', 'United States'): {'num_total': 8297,
#   'filtered_total': 366},
#  ('Plainfield', 'Illinois', 'United States'): {'num_total': 117,
#   'filtered_total': 7},
#  ('Plantation', 'Florida', 'United States'): {'num_total': 142,
#   'filtered_total': 37},
#  ('Plum', 'Pennsylvania', 'United States'): {'num_total': 560,
#   'filtered_total': 44},
#  ('Pocatello', 'Idaho', 'United States'): {'num_total': 134,
#   'filtered_total': 3},
#  ('Pompano Beach', 'Florida', 'United States'): {'num_total': 683,
#   'filtered_total': 69},
#  ('Ponce', 'Puerto Rico', 'United States'): {'num_total': 926,
#   'filtered_total': 20},
#  ('Port Angeles', 'Washington', 'United States'): {'num_total': 46,
#   'filtered_total': 1},
#  ('Port Arthur', 'Texas', 'United States'): {'num_total': 67,
#   'filtered_total': 2},
#  ('Port Orange', 'Florida', 'United States'): {'num_total': 204,
#   'filtered_total': 25},
#  ('Port St Lucie', 'Florida', 'United States'): {'num_total': 440,
#   'filtered_total': 65},
#  ('Portland', 'Maine', 'United States'): {'num_total': 1363,
#   'filtered_total': 67},
#  ('Portland', 'Oregon', 'United States'): {'num_total': 9190,
#   'filtered_total': 492},
#  ('Porto Alegre', 'Rio Grande Do Sul', 'Brazil'): {'num_total': 24399,
#   'filtered_total': 441},
#  ('Portsmouth', 'England', 'United Kingdom'): {'num_total': 162,
#   'filtered_total': 4},
#  ('Portsmouth', 'Iowa', 'United States'): {'num_total': 118,
#   'filtered_total': 5},
#  ('Portsmouth', 'Virginia', 'United States'): {'num_total': 127,
#   'filtered_total': 27},
#  ('Pottstown', 'Pennsylvania', 'United States'): {'num_total': 84,
#   'filtered_total': 4},
#  ('Prague', 'Prague', 'Czech Republic'): {'num_total': 268,
#   'filtered_total': 7},
#  ('Praia Grande', 'Sao Paulo', 'Brazil'): {'num_total': 32297,
#   'filtered_total': 456},
#  ('Princeton', 'New Jersey', 'United States'): {'num_total': 841,
#   'filtered_total': 63},
#  ('Providence', 'Rhode Island', 'United States'): {'num_total': 3487,
#   'filtered_total': 1194},
#  ('Provo', 'Utah', 'United States'): {'num_total': 214, 'filtered_total': 7},
#  ('Puebla', 'Puebla', 'Mexico'): {'num_total': 3459, 'filtered_total': 99},
#  ('Puyallup', 'Washington', 'United States'): {'num_total': 93,
#   'filtered_total': 6},
#  ('Queen City', 'Missouri', 'United States'): {'num_total': 42,
#   'filtered_total': 1},
#  ('Queens', 'New York', 'United States'): {'num_total': 1515,
#   'filtered_total': 147},
#  ('Quetzaltenango', 'Quetzaltenango', 'Guatemala'): {'num_total': 953,
#   'filtered_total': 35},
#  ('Quincy', 'Illinois', 'United States'): {'num_total': 111,
#   'filtered_total': 2},
#  ('Rabat', 'Rabat-Salé-Zemmour-Zaer', 'Morocco'): {'num_total': 243,
#   'filtered_total': 3},
#  ('Rajkot', 'Gujarat', 'India'): {'num_total': 166, 'filtered_total': 16},
#  ('Raleigh', 'North Carolina', 'United States'): {'num_total': 4179,
#   'filtered_total': 284},
#  ('Reading', 'Pennsylvania', 'United States'): {'num_total': 284,
#   'filtered_total': 17},
#  ('Redmond', 'Washington', 'United States'): {'num_total': 426,
#   'filtered_total': 39},
#  ('Redondo Beach', 'California', 'United States'): {'num_total': 1325,
#   'filtered_total': 114},
#  ('Redwood City', 'California', 'United States'): {'num_total': 560,
#   'filtered_total': 15},
#  ('Reno', 'Nevada', 'United States'): {'num_total': 1952,
#   'filtered_total': 98},
#  ('Reston', 'Virginia', 'United States'): {'num_total': 281,
#   'filtered_total': 21},
#  ('Reynoldsburg', 'Ohio', 'United States'): {'num_total': 49,
#   'filtered_total': 2},
#  ('Richardson', 'Texas', 'United States'): {'num_total': 195,
#   'filtered_total': 6},
#  ('Richfield', 'Minnesota', 'United States'): {'num_total': 87,
#   'filtered_total': 9},
#  ('Richmond', 'British Columbia', 'Canada'): {'num_total': 174,
#   'filtered_total': 23},
#  ('Richmond', 'California', 'United States'): {'num_total': 308,
#   'filtered_total': 18},
#  ('Richmond', 'Virginia', 'United States'): {'num_total': 3868,
#   'filtered_total': 303},
#  ('Rio De Janeiro', 'Rio De Janeiro', 'Brazil'): {'num_total': 142028,
#   'filtered_total': 3469},
#  ('Rio Grande', 'Rio Grande do Sul', 'Brazil'): {'num_total': 6179,
#   'filtered_total': 83},
#  ('Riverside', 'California', 'United States'): {'num_total': 1262,
#   'filtered_total': 71},
#  ('Rochester', 'Minnesota', 'United States'): {'num_total': 405,
#   'filtered_total': 28},
#  ('Rochester', 'New York', 'United States'): {'num_total': 3229,
#   'filtered_total': 158},
#  ('Rock Hill', 'South Carolina', 'United States'): {'num_total': 366,
#   'filtered_total': 40},
#  ('Rockville', 'Maryland', 'United States'): {'num_total': 1885,
#   'filtered_total': 80},
#  ('Rocky Hill', 'Connecticut', 'United States'): {'num_total': 110,
#   'filtered_total': 10},
#  ('Rome', 'Latium', 'Italy'): {'num_total': 5662, 'filtered_total': 176},
#  ('Rome', 'New York', 'United States'): {'num_total': 47, 'filtered_total': 3},
#  ('Rosario', '', 'Argentina'): {'num_total': 3811, 'filtered_total': 139},
#  ('Rosenberg', 'Texas', 'United States'): {'num_total': 1755,
#   'filtered_total': 175},
#  ('Roswell', 'Georgia', 'United States'): {'num_total': 289,
#   'filtered_total': 27},
#  ('Royal Oak', 'Michigan', 'United States'): {'num_total': 294,
#   'filtered_total': 3},
#  ('Royal Palm Beach', 'Florida', 'United States'): {'num_total': 348,
#   'filtered_total': 26},
#  ('Sacramento', 'California', 'United States'): {'num_total': 7615,
#   'filtered_total': 421},
#  ('Salem', 'Oregon', 'United States'): {'num_total': 496,
#   'filtered_total': 36},
#  ('Salem', 'Virginia', 'United States'): {'num_total': 67,
#   'filtered_total': 7},
#  ('Salinas', 'California', 'United States'): {'num_total': 339,
#   'filtered_total': 16},
#  ('Salt Lake City', 'Utah', 'United States'): {'num_total': 6448,
#   'filtered_total': 289},
#  ('Salvador', 'Bahia', 'Brazil'): {'num_total': 5397, 'filtered_total': 144},
#  ('San Andreas', 'California', 'United States'): {'num_total': 225,
#   'filtered_total': 1},
#  ('San Angelo', 'Texas', 'United States'): {'num_total': 398,
#   'filtered_total': 49},
#  ('San Antonio', 'Texas', 'United States'): {'num_total': 10171,
#   'filtered_total': 792},
#  ('San Carlos', 'California', 'United States'): {'num_total': 104,
#   'filtered_total': 7},
#  ('San Clemente', 'California', 'United States'): {'num_total': 121,
#   'filtered_total': 9},
#  ('San Diego', 'California', 'United States'): {'num_total': 14335,
#   'filtered_total': 1116},
#  ('San Jose', 'California', 'United States'): {'num_total': 3324,
#   'filtered_total': 221},
#  ('San Jose', 'San Jose', 'Costa Rica'): {'num_total': 1133,
#   'filtered_total': 80},
#  ('San José Chiapa', 'Puebla', 'Mexico'): {'num_total': 360,
#   'filtered_total': 7},
#  ('San Juan', 'Puerto Rico', 'United States'): {'num_total': 9218,
#   'filtered_total': 309},
#  ('San Luis Obispo', 'California', 'United States'): {'num_total': 339,
#   'filtered_total': 19},
#  ('San Mateo', 'California', 'United States'): {'num_total': 4233,
#   'filtered_total': 223},
#  ('San Salvador', 'San Salvador', 'El Salvador'): {'num_total': 12922,
#   'filtered_total': 705},
#  ('San Tan Valley', 'Arizona', 'United States'): {'num_total': 134,
#   'filtered_total': 5},
#  ('Sanford', 'Florida', 'United States'): {'num_total': 134,
#   'filtered_total': 14},
#  ('Santa Ana', 'California', 'United States'): {'num_total': 571,
#   'filtered_total': 28},
#  ('Santa Ana', 'Santa Ana', 'El Salvador'): {'num_total': 905,
#   'filtered_total': 13},
#  ('Santa Barbara', 'California', 'United States'): {'num_total': 1709,
#   'filtered_total': 111},
#  ('Santa Clarita', 'California', 'United States'): {'num_total': 243,
#   'filtered_total': 7},
#  ('Santa Fe', '', 'Argentina'): {'num_total': 1283, 'filtered_total': 61},
#  ('Santa Monica', 'California', 'United States'): {'num_total': 1748,
#   'filtered_total': 108},
#  ('Santa Rosa', 'California', 'United States'): {'num_total': 617,
#   'filtered_total': 32},
#  ('Santiago', 'Santiago Metropolitan', 'Chile'): {'num_total': 20027,
#   'filtered_total': 1114},
#  ('Santo Domingo',
#   'Distrito Nacional',
#   'Dominican Republic'): {'num_total': 16313, 'filtered_total': 756},
#  ('Sao Paulo', 'Sao Paulo', 'Brazil'): {'num_total': 12300,
#   'filtered_total': 305},
#  ('Sarasota', 'Florida', 'United States'): {'num_total': 3109,
#   'filtered_total': 254},
#  ('Saskatoon', 'Saskatchewan', 'Canada'): {'num_total': 702,
#   'filtered_total': 31},
#  ('Savannah', 'Georgia', 'United States'): {'num_total': 1235,
#   'filtered_total': 86},
#  ('Scottsdale', 'Arizona', 'United States'): {'num_total': 2435,
#   'filtered_total': 178},
#  ('Seattle', 'Washington', 'United States'): {'num_total': 20512,
#   'filtered_total': 1270},
#  ('Seoul', 'Seoul', 'South Korea'): {'num_total': 1931, 'filtered_total': 70},
#  ('Shah Alam', 'Selangor', 'Malaysia'): {'num_total': 1113,
#   'filtered_total': 8},
#  ('Sheboygan', 'Wisconsin', 'United States'): {'num_total': 97,
#   'filtered_total': 12},
#  ('Sheffield', 'England', 'United Kingdom'): {'num_total': 2094,
#   'filtered_total': 173},
#  ('Shepherdsville', 'Kentucky', 'United States'): {'num_total': 72,
#   'filtered_total': 5},
#  ('Sherman Oaks', 'California', 'United States'): {'num_total': 374,
#   'filtered_total': 12},
#  ('Shiprock', 'New Mexico', 'United States'): {'num_total': 116,
#   'filtered_total': 17},
#  ('Sierra Vista', 'Arizona', 'United States'): {'num_total': 48,
#   'filtered_total': 1},
#  ('Siloam Springs', 'Arkansas', 'United States'): {'num_total': 45,
#   'filtered_total': 3},
#  ('Silver Spring', 'Maryland', 'United States'): {'num_total': 3296,
#   'filtered_total': 250},
#  ('Sinaloa', 'Sinaloa', 'Mexico'): {'num_total': 443, 'filtered_total': 10},
#  ('Singapore', 'Central Singapore', 'Singapore'): {'num_total': 27435,
#   'filtered_total': 1377},
#  ('Sioux Falls', 'South Dakota', 'United States'): {'num_total': 615,
#   'filtered_total': 54},
#  ('Skokie', 'Illinois', 'United States'): {'num_total': 81,
#   'filtered_total': 4},
#  ('Smithtown', 'New York', 'United States'): {'num_total': 186,
#   'filtered_total': 24},
#  ('Smyrna', 'Tennessee', 'United States'): {'num_total': 42,
#   'filtered_total': 2},
#  ('Somerset', 'New Jersey', 'United States'): {'num_total': 102,
#   'filtered_total': 4},
#  ('Somerville', 'Massachusetts', 'United States'): {'num_total': 479,
#   'filtered_total': 30},
#  ('Sonora', 'California', 'United States'): {'num_total': 1191,
#   'filtered_total': 42},
#  ('South Bend', 'Indiana', 'United States'): {'num_total': 394,
#   'filtered_total': 25},
#  ('South San Francisco', 'California', 'United States'): {'num_total': 24993,
#   'filtered_total': 1762},
#  ('Southampton', 'England', 'United Kingdom'): {'num_total': 528,
#   'filtered_total': 8},
#  ('Southampton', 'Massachusetts', 'United States'): {'num_total': 350,
#   'filtered_total': 34},
#  ('Southfield', 'Michigan', 'United States'): {'num_total': 87,
#   'filtered_total': 2},
#  ('Southport', 'England', 'United Kingdom'): {'num_total': 11,
#   'filtered_total': 1},
#  ('Southwest', 'Pennsylvania', 'United States'): {'num_total': 282,
#   'filtered_total': 3},
#  ('Spartanburg', 'South Carolina', 'United States'): {'num_total': 273,
#   'filtered_total': 25},
#  ('Spokane', 'Missouri', 'United States'): {'num_total': 89,
#   'filtered_total': 7},
#  ('Spokane', 'Washington', 'United States'): {'num_total': 7097,
#   'filtered_total': 63},
#  ('Springfield', 'Illinois', 'United States'): {'num_total': 712,
#   'filtered_total': 50},
#  ('Springfield', 'Missouri', 'United States'): {'num_total': 859,
#   'filtered_total': 47},
#  ('Springfield', 'Tennessee', 'United States'): {'num_total': 618,
#   'filtered_total': 39},
#  ('St Augustine', 'Florida', 'United States'): {'num_total': 260,
#   'filtered_total': 13},
#  ('St Charles', 'Missouri', 'United States'): {'num_total': 36,
#   'filtered_total': 2},
#  ('St Louis', 'Missouri', 'United States'): {'num_total': 6881,
#   'filtered_total': 439},
#  ('St Paul', 'Minnesota', 'United States'): {'num_total': 895,
#   'filtered_total': 69},
#  ('St Petersburg', 'Florida', 'United States'): {'num_total': 1815,
#   'filtered_total': 143},
#  ('Stamford', 'Connecticut', 'United States'): {'num_total': 516,
#   'filtered_total': 39},
#  ('Stanford', 'California', 'United States'): {'num_total': 1483,
#   'filtered_total': 80},
#  ('State College', 'Pennsylvania', 'United States'): {'num_total': 892,
#   'filtered_total': 113},
#  ('Staten Island', 'New York', 'United States'): {'num_total': 1931,
#   'filtered_total': 176},
#  ('Sterling', 'Virginia', 'United States'): {'num_total': 301,
#   'filtered_total': 32},
#  ('Stockholm', '', 'Sweden'): {'num_total': 2925, 'filtered_total': 75},
#  ('Strongsville', 'Ohio', 'United States'): {'num_total': 36,
#   'filtered_total': 2},
#  ('Sugar Land', 'Texas', 'United States'): {'num_total': 616,
#   'filtered_total': 25},
#  ('Sungai Petani', 'Kedah', 'Malaysia'): {'num_total': 70,
#   'filtered_total': 1},
#  ('Sunnyvale', 'California', 'United States'): {'num_total': 495,
#   'filtered_total': 52},
#  ('Sunrise', 'Florida', 'United States'): {'num_total': 326,
#   'filtered_total': 35},
#  ('Surrey', 'British Columbia', 'Canada'): {'num_total': 354,
#   'filtered_total': 25},
#  ('Sussex', 'New Jersey', 'United States'): {'num_total': 150,
#   'filtered_total': 11},
#  ('Sweetwater', 'Florida', 'United States'): {'num_total': 294,
#   'filtered_total': 33},
#  ('Sydney', 'New South Wales', 'Australia'): {'num_total': 14228,
#   'filtered_total': 871},
#  ('Sylvania', 'Ohio', 'United States'): {'num_total': 113,
#   'filtered_total': 2},
#  ('Syracuse', 'New York', 'United States'): {'num_total': 1469,
#   'filtered_total': 76},
#  ('Tacoma', 'Washington', 'United States'): {'num_total': 847,
#   'filtered_total': 44},
#  ('Tahlequah', 'Oklahoma', 'United States'): {'num_total': 76,
#   'filtered_total': 1},
#  ('Takoma Park', 'Maryland', 'United States'): {'num_total': 249,
#   'filtered_total': 5},
#  ('Tallahassee', 'Florida', 'United States'): {'num_total': 6038,
#   'filtered_total': 348},
#  ('Tamarac', 'Florida', 'United States'): {'num_total': 310,
#   'filtered_total': 46},
#  ('Tampa', 'Florida', 'United States'): {'num_total': 13715,
#   'filtered_total': 1005},
#  ('Tavares', 'Florida', 'United States'): {'num_total': 52,
#   'filtered_total': 1},
#  ('Taylor', 'Michigan', 'United States'): {'num_total': 132,
#   'filtered_total': 10},
#  ('Tegucigalpa', 'Francisco Morazán', 'Honduras'): {'num_total': 6905,
#   'filtered_total': 89},
#  ('Tel Aviv', 'Tel Aviv', 'Israel'): {'num_total': 327, 'filtered_total': 14},
#  ('Temecula', 'California', 'United States'): {'num_total': 391,
#   'filtered_total': 12},
#  ('Temple', 'Texas', 'United States'): {'num_total': 164, 'filtered_total': 3},
#  ('Teresina', 'Maranhao', 'Brazil'): {'num_total': 32, 'filtered_total': 2},
#  ('The Woodlands', 'Texas', 'United States'): {'num_total': 692,
#   'filtered_total': 68},
#  ('Tinley Park', 'Illinois', 'United States'): {'num_total': 41},
#  ('Tokyo', 'Tokyo Prefecture', 'Japan'): {'num_total': 4291,
#   'filtered_total': 183},
#  ...}

# %%
final_df = pd.DataFrame(columns=['city', 'state', 'country', 'total_tweets', 
                                 'filtered_tweets', 'percentage'])
index = 0
for col in data:
    try:
        total_tweets = data[col]['num_total']
    except KeyError:
        continue
        
    try:
        filtered_tweets = data[col]['filtered_total']
    except KeyError:
        filtered_tweets = 0
        
    percentage = filtered_tweets/total_tweets * 100
    final_df.loc[index] = [col[0], col[1], col[2], total_tweets, filtered_tweets,
                          percentage]
    index += 1

# %%
final_df.to_csv("final_df.csv")

# %%
print(final_df.shape)
final_df.head()
# Out:
# (4762, 6)
#   city state      country total_tweets filtered_tweets  percentage
# 0             Afghanistan          202              11    5.445545
# 1                 Algeria          696               9    1.293103
# 2               Argentina        51622            2520    4.881640
# 3               Australia        17577             959    5.455994
# 4              Bangladesh         3247             209    6.436711

# %%
final_df[final_df['total_tweets'] >= 1000][final_df['percentage'] >= 10]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                  city           state        country total_tweets  \
# 178                            Punjab       Pakistan         1378
# 224        Alpharetta         Georgia  United States         1396
# 235          Appleton       Wisconsin  United States         1356
# 370        Charleston  South Carolina  United States         2918
# 405           Compton      California  United States         1361
# 410      Coral Gables         Florida  United States         1652
# 495   Fort Lauderdale         Florida  United States         5301
# 496        Fort Myers         Florida  United States         1138
# 538        Greenville  South Carolina  United States         1055
# 599      Jacksonville         Florida  United States         6268
# 650         Lancaster      California  United States         1116
# 684           Lubbock           Texas  United States         1340
# 715       Miami Beach         Florida  United States         6767
# 794             Omaha        Nebraska  United States         2284
# 804            Oxford         Alabama  United States         1625
# 856        Providence    Rhode Island  United States         3487
# 1000           Toledo            Ohio  United States         1091
# 1060     White Plains        New York  United States         1332
# 1087       Avellaneda                      Argentina         1012
#
#      filtered_tweets  percentage
# 178              172   12.481858
# 224              168   12.034384
# 235              217   16.002950
# 370              354   12.131597
# 405              232   17.046289
# 410              243   14.709443
# 495              531   10.016978
# 496              125   10.984183
# 538              110   10.426540
# 599              677   10.800893
# 650              250   22.401434
# 684              157   11.716418
# 715              870   12.856510
# 794              232   10.157618
# 804              237   14.584615
# 856             1194   34.241468
# 1000             111   10.174152
# 1060             175   13.138138
# 1087             122   12.055336

# %%
print(final_df['filtered_tweets'].sum())
print(final_df['total_tweets'].sum())
# Out:
# 277758
# 5492487

# %%
print("Total percentage: {:.2f}%".format(final_df['filtered_tweets'].sum()/final_df['total_tweets'].sum()*100))
# Out:
# Total percentage: 5.06%
