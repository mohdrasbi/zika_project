# %%
import pandas as pd

# %%
name = "tweets_pronounsspray_sample.csv"
df1 = pd.read_csv("tweets_pronouns.csv", lineterminator='\n')
df2 = pd.read_csv("samples_ash/{}".format(name))

# %%
indices = list(df2['Unnamed: 0'])
ids = []
for i in indices:
    ids.append(int(df1[df1['Unnamed: 0'] == i]['id']))

# %%
df2['id'] = ids

# %%
df2
# Out:
#      Unnamed: 0                                    tweets_pronouns  Notes  \
# 0         13314  COMMENTARY: Texas acting to protect unborn fro...    NaN
# 1          8240  Bee-pocalypse: What lessons did we learn from ...    NaN
# 2           769  Get our free white paper on protecting your em...    NaN
# 3         14872  Zika is a mosquito born disease and we make re...    NaN
# 4         30020  Y'all, this sh*t is for real. Wear bug spray t...    NaN
# 5          4652  We're still learning more about the effects of...    NaN
# 6         23179  @grist They can't spray me or my air in #TheOC...    NaN
# 7         16988  Not seeing as many Zika related insect repelle...    NaN
# 8          4029  I understand the need to control mosquitoes, b...    NaN
# 9         22955  #Summer is upon us &amp; #Zika is a growing co...    NaN
# 10         7140  Learn how you can protect you and your family ...    NaN
# 11        29001  So is it wrong for me to buy stocks that make ...    NaN
# ...

# %%
df2.to_csv("new_samples_ash/{}".format(name))

# %%
df1[df1['id'] == 734871303061184513
]
# Out:
#        Unnamed: 0                  id  \
# 29001       29001  734871303061184513
#
#                                                    tweet
# 29001  So is it wrong for me to buy stocks that make ...
