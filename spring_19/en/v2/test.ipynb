# %%
import pandas as pd

# %%
s = pd.read_csv("tweets_pronouns.csv", lineterminator='\n')
# Out:
#        Unnamed: 0                                    tweets_pronouns
# 0               0  Remember to Drain and Cover to prevent mosquit...
# 1               1  I trust mosquitos that carry the Zika virus mo...
# 2               2  @SenateMajLdr - Zika virus funding &amp; push ...
# 3               3  pesticides that we spray for zika kills off th...
# 4               4  Kaitlin: Brooke has a mosquito bite on her nec...
# 5               5  Things I trust more than Hillary Clinton: Zika...
# 6               6  mosquitoes are so scared of me i give them zik...
# 7               7  I liked a @YouTube video https://t.co/oB6qfpVx...
# 8               8  A new neighbor walked into the elevator as I w...
# 9               9  I liked a @YouTube video https://t.co/3p9hdE53...
# 10             10  There are 11 cases of Zika here. So i use this...
# 11             11  I Have ten Mosquito Bites FUCK Me Huh. Guess I...
# 12             12  There's a mosquito in my room I'm gonna get Zi...
# ...
